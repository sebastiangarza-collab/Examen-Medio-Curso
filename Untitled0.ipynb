# %%
#codigo examen Análisis del dataset Diamonds
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv"
df = pd.read_csv(url)

# %%
# Últimas 5 filas
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
# Resumen estadístico de columnas numéricas
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
# Buscar filas donde x, y o z sean iguales a 0
filas_invalidas = df[(df["x"] == 0) | (df["y"] == 0) | (df["z"] == 0)]

print("Cantidad de filas con dimensiones inválidas:", len(filas_invalidas))
filas_invalidas.head()
# Out:
# Cantidad de filas con dimensiones inválidas: 20
#        carat      cut color clarity  depth  table  price     x     y    z
# 2207    1.00  Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01  Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10  Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01  Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50     Good     G      I1   64.0   61.0   4731  7.15  7.04  0.0

# %%
# Eliminar las filas inválidas
df = df[(df["x"] != 0) & (df["y"] != 0) & (df["z"] != 0)].copy()

print("Nuevo tamaño del DataFrame:", df.shape)
# Out:
# Nuevo tamaño del DataFrame: (53920, 10)

# %%
# Crear nueva columna de volumen_aprox
df["volumen_aprox"] = df["x"] * df["y"] * df["z"]

df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    volumen_aprox
# 0      38.202030
# 1      34.505856
# 2      38.076885
# 3      46.724580
# 4      51.917250

# %%
#Parte 2 Visualizar Datos
plt.figure(figsize=(8,5))
plt.boxplot(df["price"])
plt.title("Distribución del precio de los diamantes")
plt.ylabel("Precio")
plt.xlabel("Diamantes")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["volumen_aprox"], df["price"], alpha=0.5)
plt.title("Relación entre volumen aproximado y precio")
plt.xlabel("Volumen aproximado")
plt.ylabel("Precio")
plt.show()

# %%
conteo_cut = df["cut"].value_counts()

plt.figure(figsize=(8,5))
plt.bar(conteo_cut.index, conteo_cut.values)
plt.title("Cantidad de diamantes por tipo de corte")
plt.xlabel("Tipo de corte")
plt.ylabel("Cantidad")
plt.xticks(rotation=45)
plt.show()
